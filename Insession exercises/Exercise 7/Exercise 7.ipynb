# %% [markdown]
# # What to do

# %% [markdown]
# Dataset: The Titanic dataset: [Titanic Dataset](https://web.stanford.edu/class/archive/cs/cs109/cs109.1166/stuff/titanic.csv)\
# Time: 25 minutes
# Instructions:
# 1. **Load the Data:**
#     Import the necessary libraries (pandas,matplotlib,seaborn).
#     Load the Titanic dataset into a Pandas DataFrame.
# 2. **Visualization:**
#     Create a bar plot showing the count of passengers by Pclass ( passenger class )
#     Create the bar plot twice: once using Seaborn and once using Matplotlib.
# 3. **Design Principles:**
#     Ensure the plot has an appropriate title, and axis labels for readability.
#     Use a uniformed color for all bars.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('./titanic.csv')

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                             Mr. Owen Harris Braund
# 1         1       1  Mrs. John Bradley (Florence Briggs Thayer) Cum...
# 2         1       3                              Miss. Laina Heikkinen
# 3         1       1        Mrs. Jacques Heath (Lily May Peel) Futrelle
# 4         0       3                            Mr. William Henry Allen
#
#       Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard     Fare
# 0    male  22.0                        1                        0   7.2500
# 1  female  38.0                        1                        0  71.2833
# 2  female  26.0                        0                        0   7.9250
# 3  female  35.0                        1                        0  53.1000
# 4    male  35.0                        0                        0   8.0500

# %% [markdown]
# # Getting the number of passengers per class

# %%
passengers_per_class = df['Pclass'].value_counts().sort_index()

# %%
passengers_per_class
# Out:
# Pclass
# 1    216
# 2    184
# 3    487
# Name: count, dtype: int64

# %% [markdown]
# # Plots

# %% [markdown]
# ## Plot in Matplotlib

# %% [markdown]
# ### Bar Chart

# %%
plt.bar

# %%
plt.bar(passengers_per_class.index, passengers_per_class.values, color='lightgreen') 

plt.title('Number of Passengers per Class (Matplotlib)',fontsize=18,pad=20)
plt.xlabel('Passenger Class',fontsize=14,labelpad=5) 
plt.ylabel('Count',fontsize=14,labelpad=10)

plt.xticks(class_counts.index)

plt.show()

# %% [markdown]
# ### Pie Chart

# %%
classes = []
for label in passengers_per_class.index:
    classes.append('Class ' + str(label))

plt.pie(passengers_per_class.values, labels=classes,autopct='%1.1f%%',startangle=0) 

plt.title('Number of Passengers per Class (Matplotlib)')


plt.show()

# %% [markdown]
# ## Plot in Seaborn

# %%
sns.countplot

# %%
sns.countplot(data=df, x='Pclass', color='purple').set_title('Number of Passengers per Class (Seaborn)');
