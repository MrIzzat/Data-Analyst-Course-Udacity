# %% [markdown]
# # Group members

# %% [markdown]
# # What to do
#
# Time: 45 Minutes
# - TODO: Download the movies.csv file manually using the following link, upload it to your
# workspace, read it using pandas, and assess, and clean as many as issues you can.
# - Dataset Link:
# https: //www.kaggle.com/datasets/vinifm/female-representation-in-cinema?select=movies.csv
# - Save cleaned dataset/datasets.
# - For Present The Cleaned Dataset/Datasets: Please choose one of you to talk about the group and present the final dataset/datasets after cleaning.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Read data

# %%
df = pd.read_csv('movies.csv')

# %% [markdown]
# # Initial viewing of data

# %%
df.head(4)
# Out:
#    Unnamed: 0                      title  year  bt_score  dubious  imdbid  \
# 0           0                 Cinderella  1899         3        0     230
# 1           1     Gretchen the Greenhorn  1916         3        0    6745
# 2           2                 Snow White  1916         3        0    7361
# 3           3  The Poor Little Rich Girl  1917         3        0    8443
#
#    tmdbId                                     genres  popularity  \
# 0  114108  ['Drama', 'Family', 'Fantasy', 'Romance']       3.762
# 1  126925                                         []       1.942
# 2  174598                       ['Fantasy', 'Drama']       0.817
# 3   95866  ['Romance', 'Comedy', 'Drama', 'Fantasy']       2.023
#
#                 production_companies  ... revenue vote_average  vote_count  \
# 0    ['Star-Film', 'Georges Méliès']  ...     0.0          6.1        79.0
# 1                                 []  ...     0.0          6.1         7.0
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'title', 'year', 'bt_score', 'dubious', 'imdbid',
#        'tmdbId', 'genres', 'popularity', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'vote_average',
#        'vote_count', 'cast', 'crew', 'budget', 'cast_gender', 'crew_gender',
#        'cast_female_representation', 'crew_female_representation'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7279 entries, 0 to 7278
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  7279 non-null   int64
#  1   title                       7279 non-null   object
#  2   year                        7279 non-null   int64
#  3   bt_score                    7279 non-null   int64
#  4   dubious                     7279 non-null   int64
#  5   imdbid                      7279 non-null   int64
#  6   tmdbId                      7279 non-null   int64
#  7   genres                      7279 non-null   object
#  8   popularity                  7279 non-null   float64
#  9   production_companies        7279 non-null   object
#  10  production_countries        7279 non-null   object
#  11  release_date                7279 non-null   object
#  12  revenue                     7279 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0         year     bt_score      dubious        imdbid  \
# count  7279.000000  7279.000000  7279.000000  7279.000000  7.279000e+03
# mean   3818.383294  1994.332051     2.106745     0.090809  9.139360e+05
# std    2203.194535    23.330282     1.097980     0.287357  1.175348e+06
# min       0.000000  1878.000000     0.000000     0.000000  1.000000e+00
# 25%    1920.500000  1985.000000     1.000000     0.000000  9.087300e+04
# 50%    3825.000000  2003.000000     3.000000     0.000000  3.324520e+05
# 75%    5695.500000  2011.000000     3.000000     0.000000  1.465051e+06
# max    7634.000000  2020.000000     3.000000     1.000000  6.536944e+06
#
#               tmdbId   popularity       revenue  vote_average    vote_count  \
# count    7279.000000  7279.000000  7.279000e+03   7279.000000   7279.000000
# mean    71338.645968    18.684234  5.756087e+07      6.545569   1402.759445
# std    101324.323243    38.012652  1.423315e+08      0.836113   2683.199152
# ...

# %% [markdown]
# # Cleaning process

# %%
genres = df['genres']
genres
# Out:
# 0               ['Drama', 'Family', 'Fantasy', 'Romance']
# 1                                                      []
# 2                                    ['Fantasy', 'Drama']
# 3               ['Romance', 'Comedy', 'Drama', 'Fantasy']
# 4                                               ['Drama']
#                               ...
# 7274                           ['War', 'Action', 'Drama']
# 7275                                 ['Comedy', 'Family']
# 7276                                 ['Romance', 'Drama']
# 7277    ['Science Fiction', 'Animation', 'Action', 'Cr...
# 7278                           ['Comedy', 'Drama', 'War']
# Name: genres, Length: 7279, dtype: object

# %%
df_genres = pd.DataFrame(genres)
df_genres
# Out:
#                                                  genres
# 0             ['Drama', 'Family', 'Fantasy', 'Romance']
# 1                                                    []
# 2                                  ['Fantasy', 'Drama']
# 3             ['Romance', 'Comedy', 'Drama', 'Fantasy']
# 4                                             ['Drama']
# ...                                                 ...
# 7274                         ['War', 'Action', 'Drama']
# 7275                               ['Comedy', 'Family']
# 7276                               ['Romance', 'Drama']
# 7277  ['Science Fiction', 'Animation', 'Action', 'Cr...
# 7278                         ['Comedy', 'Drama', 'War']
#
# [7279 rows x 1 columns]

# %%
df_genres.duplicated().sum()
# Out:
# 5632

# %%
df_genres.drop_duplicates(inplace=True)

# %%
df_genres.duplicated().sum()
# Out:
# 0

# %%
df_test = df_genres

# %%
df_test.explode('genres')
# Out:
#                                                  genres
# 0             ['Drama', 'Family', 'Fantasy', 'Romance']
# 1                                                    []
# 2                                  ['Fantasy', 'Drama']
# 3             ['Romance', 'Comedy', 'Drama', 'Fantasy']
# 4                                             ['Drama']
# ...                                                 ...
# 7267        ['Animation', 'Drama', 'Fantasy', 'Family']
# 7268                   ['Horror', 'Fantasy', 'Mystery']
# 7271                   ['Drama', 'Animation', 'Horror']
# 7273                       ['War', 'Thriller', 'Drama']
# 7277  ['Science Fiction', 'Animation', 'Action', 'Cr...
#
# [1647 rows x 1 columns]

# %%
genres_df = df[['imdbid','genres']]
genres_df.head()
# Out:
#    imdbid                                     genres
# 0     230  ['Drama', 'Family', 'Fantasy', 'Romance']
# 1    6745                                         []
# 2    7361                       ['Fantasy', 'Drama']
# 3    8443  ['Romance', 'Comedy', 'Drama', 'Fantasy']
# 4    9652                                  ['Drama']

# %%
genres_df
# Out:
#        imdbid                                             genres
# 0         230          ['Drama', 'Family', 'Fantasy', 'Romance']
# 1        6745                                                 []
# 2        7361                               ['Fantasy', 'Drama']
# 3        8443          ['Romance', 'Comedy', 'Drama', 'Fantasy']
# 4        9652                                          ['Drama']
# ...       ...                                                ...
# 7274  2582576                         ['War', 'Action', 'Drama']
# 7275  6003368                               ['Comedy', 'Family']
# 7276  5635086                               ['Romance', 'Drama']
# 7277  4717402  ['Science Fiction', 'Animation', 'Action', 'Cr...
# 7278  4758646                         ['Comedy', 'Drama', 'War']
#
# [7279 rows x 2 columns]

# %%
genres_df.genres = genres_df.genres.apply(literal_eval)
genres_df = genres_df.explode('genres', ignore_index=True)

genres_df
# Out:
# C:\Users\MrIzzat\AppData\Local\Temp\ipykernel_16072\403435324.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   genres_df.genres = genres_df.genres.apply(literal_eval)
#         imdbid   genres
# 0          230    Drama
# 1          230   Family
# 2          230  Fantasy
# 3          230  Romance
# 4         6745      NaN
# ...        ...      ...
# 17982  4717402   Action
# 17983  4717402    Crime
# 17984  4758646   Comedy
# 17985  4758646    Drama
# 17986  4758646      War
#
# [17987 rows x 2 columns]

# %%
genres_df.dropna(inplace=True)

# %%
genres_df.drop_duplicates(inplace=True)

# %%
genres_df
# Out:
#         imdbid   genres
# 0          230    Drama
# 1          230   Family
# 2          230  Fantasy
# 3          230  Romance
# 5         7361  Fantasy
# ...        ...      ...
# 17982  4717402   Action
# 17983  4717402    Crime
# 17984  4758646   Comedy
# 17985  4758646    Drama
# 17986  4758646      War
#
# [17965 rows x 2 columns]

# %%
df_genres.dropna(inplace=True)

# %%
df_genres.drop_duplicates(inplace=True)

# %%
df_genres
# Out:
#               genres
# 0              Drama
# 1             Family
# 2            Fantasy
# 3            Romance
# 17           History
# 19       Documentary
# 24           Mystery
# 25          Thriller
# 29            Comedy
# 42             Crime
# 46            Horror
# 51             Music
# 53            Action
# 65           Western
# 74         Adventure
# 114  Science Fiction
# 131        Animation
# 171              War
# 634         TV Movie

# %%
(df_genres=='Action').argmax()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16072\3767150989.py in ?()
# ----> 1 (df_genres=='Action').argmax()
#
# ~\Documents\Data Analysis Course\env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'argmax'

# %%
df_genres.genres.loc['Action']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Documents\Data Analysis Course\env\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:175, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Action'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 df_genres.genres.loc['Action']
#
# File ~\Documents\Data Analysis Course\env\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
# ...

# %%
genres_df.genres.replace()
# Out:
# C:\Users\MrIzzat\AppData\Local\Temp\ipykernel_16072\1370897643.py:1: FutureWarning: DataFrame.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   genres_df.replace()
#         imdbid   genres
# 0          230    Drama
# 1          230   Family
# 2          230  Fantasy
# 3          230  Romance
# 5         7361  Fantasy
# ...        ...      ...
# 17982  4717402   Action
# 17983  4717402    Crime
# 17984  4758646   Comedy
# 17985  4758646    Drama
# 17986  4758646      War
#
# [17965 rows x 2 columns]
