# %% [markdown]
# Usually, data is intereperted linearly. But in some cases, it may be more beneficial to interpert data in ratios or percentages. Using log transformations, the x axis becomes written in the form of multplication rather than addition. In other words, the x axis will increase in terms of multiplication instead of addition.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %config InlineBackend.figure_format = "retina"

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('diamonds.csv')

# %% [markdown]
# # Scaling x-axis to log-type

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(12,4))

sns.histplot(data=df, x='price', bins=101, ax=ax1)#Normal plot

sns.histplot(data=df, x='price', bins=101, ax=ax2)#Applied log scaling
ax2.set_xscale('log')
ax2.set_xlabel('Price (log)');

# %% [markdown]
# # Scaling x-axis to log-type and changing the axis limit

# %%
print(df['price'].describe())

np.log10(df['price'].describe())
# Out:
# count    53940.000000
# mean      3932.799722
# std       3989.439738
# min        326.000000
# 25%        950.000000
# 50%       2401.000000
# 75%       5324.250000
# max      18823.000000
# Name: price, dtype: float64
# count    4.731911
# mean     3.594702
# std      3.600912
# min      2.513218
# 25%      2.977724
# 50%      3.380392
# 75%      3.726258
# max      4.274689
# Name: price, dtype: float64

# %%
bins = 10** np.arange(2, 5+0.1, 0.1)

sns.histplot(data=df, x='price', bins=bins);

plt.xscale('log')

# %% [markdown]
# # Scaling the x-axis to log-type, changing the axis limits and increasing the x-ticks

# %%
bins = 10 ** np.arange(2, 5+0.1, 0.1)

ticks = [100, 300, 1000, 3000, 10000, 30000]

labels = [f'{v}' for v in ticks] # Converting ticks to string values

sns.histplot(data=df, x='price', bins=bins)

plt.xscale('log')
plt.xticks(ticks,labels);

# %% [markdown]
# # Custom scaling a given data series

# %%
#This code is very slow since calculations are being done in raw python

def sqrt_transformation(x, inverse=False):
    if inverse:
        return x**2
    else:
        return np.sqrt(x)

bin_edges = np.arange(0, sqrt_transformation(df['price'].max()+1, 1))

plt.hist(df['price'].apply(sqrt_transformation), bins=bin_edges)

tick_locs = np.arange(0,sqrt_transformation(df['price'].max()+20,20))

plt.xticks(ticks_locs, sqrt_transformation(tick_locs, inverse=True).astype(int));
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 11
#       7         return np.sqrt(x)
#       9 bin_edges = np.arange(0, sqrt_transformation(df['price'].max()+1, 1))
# ---> 11 plt.hist(df['price'].apply(sqrt_transformation), bins=bin_edges)
#      13 tick_locs = np.arange(0,sqrt_transformation(df['price'].max()+20,20))
#      15 plt.xticks(ticks_locs, sqrt_transformation(tick_locs, inverse=True).astype(int))
#
# File ~\Documents\Data Analysis Course\env\Lib\site-packages\matplotlib\pyplot.py:3236, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    3211 @_copy_docstring_and_deprecators(Axes.hist)
#    3212 def hist(
#    3213     x: ArrayLike | Sequence[ArrayLike],
#    (...)
#    3234     BarContainer | Polygon | list[BarContainer | Polygon],
#    3235 ]:
# ...
