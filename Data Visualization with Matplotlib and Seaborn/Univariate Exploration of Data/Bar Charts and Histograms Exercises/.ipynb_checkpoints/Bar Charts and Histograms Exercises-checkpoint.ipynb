# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Diamonds Dataset

# %%
df = pd.read_csv('./diamonds.csv')
df.shape
# Out:
# (53940, 10)

# %%
df.head(4)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63

# %% [markdown]
# # Exercise 1: Bar Charts

# %% [markdown]
# Create a count plot showing the distribution of diamond `cut`. Pick a color (e.g., blue) and make sure all bars show that color. Order the bars from lowest quality to highest quality.

# %%
order = ['Fair','Good', 'Very Good','Premium','Ideal']

# %%
sns.countplot(data=df, x='cut',color='blue',order=order);

# %% [markdown]
# # Exercise 2: Bar Charts

# %% [markdown]
# Visualize a _relative frequency plot_ of diamond `color`, and plot the results using either `matplotlib` or `seaborn`. The order should be from highest quality color grade to lowest (diamond color is graded on an alphabetical scale, with `D` the highest grade and `J` the lowest). Make sure the bar plot is plotted using a horizontal orientation.

# %%
proportions = df['color'].value_counts(normalize=True)
proportions.sort_index(inplace=True)

proportions = proportions.reset_index(drop=False)
proportions = proportions.rename(columns={'index':'color'})
proportions['proportion'] = proportions['proportion'].apply(lambda x: round(x*100,1))

proportions
# Out:
#   color  proportion
# 0     D        12.6
# 1     E        18.2
# 2     F        17.7
# 3     G        20.9
# 4     H        15.4
# 5     I        10.1
# 6     J         5.2

# %%
sns.barplot(data=proportions, x='proportion', y='color');

# %% [markdown]
# # Exercise 3: Histograms

# %% [markdown]
# Using matplotlib, plot the diamond `x` size using matplotlib. Use 0.25 mm bins, from 0 to 11 mm. Feel free to experiment and see if you can find a better bin size!

# %%
bins = np.arange(0,df['x'].max()+0.25,0.25)

plt.hist(data=df, x='x',bins=bins);

# %% [markdown]
# # Exercise 4:

# %% [markdown]
# Now using seaborn, plot the diamond `x`, `y,` and `z` sizes. The same binning as before.

# %%
df['index'] = df.index

df_long = df.melt(id_vars=['index'], value_vars = ['x', 'y', 'z'], var_name='dimension', value_name='size')

df_long.shape, df_long.head()
# Out:
# ((161820, 3),
#     index dimension  size
#  0      0         x  3.95
#  1      1         x  3.89
#  2      2         x  4.05
#  3      3         x  4.20
#  4      4         x  4.34)

# %%
sns.histplot(data=df_long, x='size',hue='dimension',bins=bins);

# %%
sns.histplot(data=df, x='x',color='lightblue',bins=bins);
sns.histplot(data=df, x='y',color='orange',bins=bins);
sns.histplot(data=df, x='z',color='lightgreen',bins=bins);

# %% [markdown]
# ## Looks way better split into 3 subplots

# %%
plt.figsize=([20,5])

plt.subplot(2,2,1)
plt.hist(data=df, x='x',bins=bins);

plt.subplot(2,2,2)
plt.hist(data=df, x='y',bins=bins);

plt.subplot(2,2,3)
plt.hist(data=df, x='z',bins=bins);

# %% [markdown]
# # Exercise 5: Histogram normalization

# %% [markdown]
# Using seaborn, plot the diamond price distribution. Using approximately 50 bins, what rough percentage of diamonds cost `~$2500`?

# %%
sns.histplot(data=df, x='price', stat='percent', bins=50);

# %% [markdown]
# around 9% of diamons cost around 2500$
