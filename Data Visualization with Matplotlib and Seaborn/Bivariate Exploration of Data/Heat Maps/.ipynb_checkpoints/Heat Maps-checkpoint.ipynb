# %% [markdown]
# **Heat Maps** is a 2D version of a histogram that can be used as an alternative to the scatter plot. Instead of idicating a numeric value by the size of the bar, it instead uses numbers with colors representing a range of numbers. It's great for viewing the density of data.
#
# Heat maps are preferred when comparing two discrete variables. It's also a great alternative to transparency in  scatter plot.
#
# Bin sizes are important to take into account.

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format='retina'

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('fuel-econ.csv')

# %% [markdown]
# # Example 1: Default Heat map plot using `Matplotlib.pyplot.hist2d()`

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(18,6))

sns.regplot(data=df, x='displ', y='comb', x_jitter=0.04, scatter_kws={'alpha':1/10}, fit_reg=False, ax=ax1)
ax1.set_xlabel('Displacement (1)')
ax1.set_ylabel('Combined Fuel Eff. (mpg)')

h = ax2.hist2d(data=df, x='displ', y='comb')

fig.colorbar(h[3],ax=ax2)

ax2.set_xlabel('Displacement (1)')
ax2.set_ylabel('Combined Fuel Eff. (mpg)')

;
# Out:
# ''

# %% [markdown]
# ## Changing the color pallete

# %%
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
#  'Set1',
#  'Set2',
#  'Set3',
#  'tab10',
#  'tab20',
#  'tab20b',
#  'tab20c',
#  'grey',
#  'gist_grey',
#  'gist_yerg',
#  'Grays',
#  'magma_r',
#  'inferno_r',
#  'plasma_r',
#  'viridis_r',
#  'cividis_r',
#  'twilight_r',
#  'twilight_shifted_r',
#  'turbo_r',
#  'Blues_r',
#  'BrBG_r',
#  'BuGn_r',
#  'BuPu_r',
#  'CMRmap_r',
#  'GnBu_r',
#  'Greens_r',
#  'Greys_r',
#  'OrRd_r',
#  'Oranges_r',
#  'PRGn_r',
#  'PiYG_r',
#  'PuBu_r',
#  'PuBuGn_r',
#  'PuOr_r',
#  'PuRd_r',
#  'Purples_r',
#  'RdBu_r',
#  'RdGy_r',
#  'RdPu_r',
#  'RdYlBu_r',
#  'RdYlGn_r',
#  'Reds_r',
#  'Spectral_r',
#  'Wistia_r',
#  'YlGn_r',
#  'YlGnBu_r',
#  'YlOrBr_r',
#  'YlOrRd_r',
#  'afmhot_r',
#  'autumn_r',
#  'binary_r',
#  'bone_r',
#  'brg_r',
#  'bwr_r',
#  'cool_r',
#  'coolwarm_r',
#  'copper_r',
#  'cubehelix_r',
#  'flag_r',
#  'gist_earth_r',
#  'gist_gray_r',
#  'gist_heat_r',
#  'gist_ncar_r',
#  'gist_rainbow_r',
#  'gist_stern_r',
#  'gist_yarg_r',
#  'gnuplot_r',
#  'gnuplot2_r',
#  'gray_r',
#  'hot_r',
#  'hsv_r',
#  'jet_r',
#  'nipy_spectral_r',
#  'ocean_r',
#  'pink_r',
#  'prism_r',
#  'rainbow_r',
#  'seismic_r',
#  'spring_r',
#  'summer_r',
#  'terrain_r',
#  'winter_r',
#  'Accent_r',
#  'Dark2_r',
#  'Paired_r',
#  'Pastel1_r',
#  'Pastel2_r',
#  'Set1_r',
#  'Set2_r',
#  'Set3_r',
#  'tab10_r',
#  'tab20_r',
#  'tab20b_r',
#  'tab20c_r',
#  'rocket',
#  'rocket_r',
#  'mako',
#  'mako_r',
#  'icefire',
#  'icefire_r',
#  'vlag',
#  'vlag_r',
#  'flare',
#  'flare_r',
#  'crest',
#  'crest_r']

# %%
fig, (ax1, ax2) = plt.subplots(1,2, figsize=(18,6))

sns.regplot(data=df, x='displ', y='comb', x_jitter=0.04, scatter_kws={'alpha':1/10}, fit_reg=False, ax=ax1)
ax1.set_xlabel('Displacement (1)')
ax1.set_ylabel('Combined Fuel Eff. (mpg)')

h = ax2.hist2d(data=df, x='displ', y='comb', cmap = "Reds")

fig.colorbar(h[3],ax=ax2)

ax2.set_xlabel('Displacement (1)')
ax2.set_ylabel('Combined Fuel Eff. (mpg)')

;
# Out:
# ''

# %% [markdown]
# # Example 2: Set a minimum bound on counts and change color map

# %% [markdown]
# The `cmap` parameter can be used to change the color pallete (which can be viewed using `plt.colormaps()`). The `cmin` paramter can be used to specify the minimum value to be given a color, anything lower will not be given a color.

# %%
plt.hist2d(data=df, x='displ', y='comb', cmap = "Spectral")

plt.colorbar()

ax2.set_xlabel('Displacement (1)')
ax2.set_ylabel('Combined Fuel Eff. (mpg)')

;
# Out:
# ''

# %%
plt.hist2d(data=df, x='displ', y='comb', cmap = "Spectral", cmin=0.5)

plt.colorbar()

ax2.set_xlabel('Displacement (1)')
ax2.set_ylabel('Combined Fuel Eff. (mpg)')

;
# Out:
# ''

# %% [markdown]
# # Example 3: Specify bin edges

# %%
bins_x = np.arange(0.6, 7+0.3, 0.3)
bins_y = np.arange(12, 58+3, 3)

plt.hist2d(data=df, x= 'displ', y='comb', cmin=0.5, cmap='viridis_r', bins=[bins_x, bins_y])
plt.colorbar()
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff. (mpg)')
;
# Out:
# ''

# %% [markdown]
# # Example 4: Add text annotation on each cell

# %% [markdown]
# This can be done with `plt.text()`, but they have to be added one by one. If there are too many cells, it's best not to use text annotations.

# %%
bins_x = np.arange(0.6, 7+0.7, 0.7)
bins_y = np.arange(12, 58+7, 7)

h2d = plt.hist2d(data=df, x= 'displ', y='comb', cmin=0.5, cmap='viridis_r', bins=[bins_x, bins_y])
plt.colorbar()
plt.xlabel('Displacement (1)')
plt.ylabel('Combined Fuel Eff. (mpg)')

counts = h2d[0]

#Looping through each ecell and and a text annotation for each
for i in range(counts.shape[0]):
    for j in range(counts.shape[1]):
        c = counts[i,j]

        if c >= 100: # If the cell is darker, make the text white
            plt.text(bins_x[i]+ 0.35, bins_y[j]+3.5, int(c),
                    ha='center',va='center', color='white')
        elif c>0:
            plt.text(bins_x[i]+0.35, bins_y[j]+3.5, int(c),
                    ha='center',va='center', color='black')           

;
# Out:
# ''

# %% [markdown]
# # Heat Maps in Seaborn

# %% [markdown]
# Even though it's similar to the the heat map made with matplotlib, it's technically classified under a categorical plot rather than a quantative to quantative plot. With seaborn, it's better to use the `histplot` function.

# %%
ax = sns.histplot(data=df, x='displ', y='comb', bins=[bins_x, bins_y], cmap='viridis_r', cbar=True)
ax.set_xlabel('Displacement (1)')
ax.set_ylabel('Combined Fuel Eff. (mpg)')
;
# Out:
# ''

# %% [markdown]
# ## How `sns.heatmap()` is used

# %%
sns.heatmap(data=df.pivot(index=["id"],columns=["fuelType"],values="city"));

# %%
df2 = pd.crosstab(df['fuelType'], df['make'])
plt.figure(figsize=(15,5))
sns.heatmap(df2);

# %%
df2 = pd.crosstab(df['fuelType'], df['make'])
plt.figure(figsize=(15,5))
sns.heatmap(df2, annot= True, annot_kws={'rotation': 90},  fmt='g');#fmt='g' make sure numbers with more than two digits are not writtein in exponential form
                                                                    #fmt='d' can be used as well

# %%
df2 = pd.crosstab(df['make'],df['fuelType'])
plt.figure(figsize=(15,10))
sns.heatmap(df2, annot= True,fmt='g');

# %%
df2 = pd.crosstab(df['fuelType'], df['make']).div(len(df))
plt.figure(figsize=(15,5))
sns.heatmap(df2, annot= True, annot_kws={'rotation': 90});

# %% [markdown]
# More information about this kind of heat maps can be found in Clustered Bar Charts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3929 entries, 0 to 3928
# Data columns (total 20 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         3929 non-null   int64
#  1   make       3929 non-null   object
#  2   model      3929 non-null   object
#  3   year       3929 non-null   int64
#  4   VClass     3929 non-null   object
#  5   drive      3929 non-null   object
#  6   trans      3929 non-null   object
#  7   fuelType   3929 non-null   object
#  8   cylinders  3929 non-null   int64
#  9   displ      3929 non-null   float64
#  10  pv2        3929 non-null   int64
#  11  pv4        3929 non-null   int64
#  12  city       3929 non-null   float64
#  13  UCity      3929 non-null   float64
#  14  highway    3929 non-null   float64
#  15  UHighway   3929 non-null   float64
#  16  comb       3929 non-null   float64
#  17  co2        3929 non-null   int64
#  18  feScore    3929 non-null   int64
#  19  ghgScore   3929 non-null   int64
# dtypes: float64(6), int64(8), object(6)
# memory usage: 614.0+ KB

# %%
df.head(1)
# Out:
#       id    make model  year           VClass            drive  \
# 0  32204  Nissan  GT-R  2013  Subcompact Cars  All-Wheel Drive
#
#              trans          fuelType  cylinders  displ  pv2  pv4     city  \
# 0  Automatic (AM6)  Premium Gasoline          6    3.8   79    0  16.4596
#
#      UCity  highway  UHighway     comb  co2  feScore  ghgScore
# 0  20.2988  22.5568   30.1798  18.7389  471        4         4

# %%
df2
# Out:
# make                  Acura  Alfa Romeo  Aston Martin      Audi       BMW  \
# fuelType
# Diesel             0.000000    0.000000      0.000000  0.002545  0.004581
# Midgrade Gasoline  0.000000    0.000000      0.000000  0.000000  0.000000
# Natural Gas        0.000000    0.000000      0.000000  0.000000  0.000000
# Premium Gasoline   0.011708    0.001527      0.003818  0.044795  0.128531
# Regular Gasoline   0.000000    0.000000      0.000000  0.003818  0.000000
#
# make                Bentley     Buick  Cadillac  Chevrolet  Chrysler  ...  \
# fuelType                                                              ...
# Diesel             0.000000  0.000000  0.000000   0.002036  0.000000  ...
# Midgrade Gasoline  0.000000  0.000000  0.000000   0.000000  0.002036  ...
# Natural Gas        0.000000  0.000000  0.000000   0.000000  0.000000  ...
# Premium Gasoline   0.011453  0.001527  0.012726   0.008908  0.000509  ...
# Regular Gasoline   0.000000  0.015271  0.017307   0.043013  0.012217  ...
#
# make                 Nissan   Porsche  Rolls-Royce  Roush Performance  \
# fuelType
# Diesel             0.000000  0.000000      0.00000           0.000000
# Midgrade Gasoline  0.000000  0.000000      0.00000           0.000000
# Natural Gas        0.000000  0.000000      0.00000           0.000000
# Premium Gasoline   0.004836  0.059812      0.01069           0.002545
# Regular Gasoline   0.013235  0.000000      0.00000           0.000000
#
# make                  Scion    Subaru    Suzuki    Toyota  Volkswagen  \
# fuelType
# Diesel             0.000000  0.000000  0.000000  0.000000    0.007126
# Midgrade Gasoline  0.000000  0.000000  0.000000  0.000000    0.000000
# Natural Gas        0.000000  0.000000  0.000000  0.000000    0.000000
# Premium Gasoline   0.002036  0.007636  0.000000  0.001018    0.014253
# Regular Gasoline   0.004836  0.007636  0.003309  0.028506    0.022907
#
# make                  Volvo
# fuelType
# Diesel             0.000000
# Midgrade Gasoline  0.000000
# Natural Gas        0.000000
# Premium Gasoline   0.003309
# Regular Gasoline   0.009417
#
# [5 rows x 39 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, Diesel to Regular Gasoline
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Acura              5 non-null      float64
#  1   Alfa Romeo         5 non-null      float64
#  2   Aston Martin       5 non-null      float64
#  3   Audi               5 non-null      float64
#  4   BMW                5 non-null      float64
#  5   Bentley            5 non-null      float64
#  6   Buick              5 non-null      float64
#  7   Cadillac           5 non-null      float64
#  8   Chevrolet          5 non-null      float64
#  9   Chrysler           5 non-null      float64
#  10  Dodge              5 non-null      float64
#  11  Ferrari            5 non-null      float64
#  12  Fiat               5 non-null      float64
#  13  Ford               5 non-null      float64
#  14  Genesis            5 non-null      float64
#  15  Honda              5 non-null      float64
#  16  Hyundai            5 non-null      float64
#  17  Infiniti           5 non-null      float64
#  18  Jaguar             5 non-null      float64
#  19  Karma              5 non-null      float64
#  20  Kia                5 non-null      float64
#  21  Lexus              5 non-null      float64
#  22  Lincoln            5 non-null      float64
#  23  Lotus              5 non-null      float64
#  24  MINI               5 non-null      float64
#  25  Maserati           5 non-null      float64
#  26  Mazda              5 non-null      float64
#  27  Mercedes-Benz      5 non-null      float64
#  28  Mitsubishi         5 non-null      float64
#  29  Nissan             5 non-null      float64
#  30  Porsche            5 non-null      float64
#  31  Rolls-Royce        5 non-null      float64
#  32  Roush Performance  5 non-null      float64
#  33  Scion              5 non-null      float64
#  34  Subaru             5 non-null      float64
#  35  Suzuki             5 non-null      float64
#  36  Toyota             5 non-null      float64
#  37  Volkswagen         5 non-null      float64
#  38  Volvo              5 non-null      float64
# dtypes: float64(39)
# memory usage: 1.6+ KB
