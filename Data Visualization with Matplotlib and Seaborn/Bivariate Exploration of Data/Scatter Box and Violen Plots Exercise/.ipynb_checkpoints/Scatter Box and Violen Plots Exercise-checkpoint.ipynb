# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format ="retina"

# %% [markdown]
# # Load Dataset

# %%
df = pd.read_csv('fuel-econ.csv')

# %%
df.shape
# Out:
# (3929, 20)

# %%
df.head(4)
# Out:
#       id        make       model  year           VClass              drive  \
# 0  32204      Nissan        GT-R  2013  Subcompact Cars    All-Wheel Drive
# 1  32205  Volkswagen          CC  2013     Compact Cars  Front-Wheel Drive
# 2  32206  Volkswagen          CC  2013     Compact Cars  Front-Wheel Drive
# 3  32207  Volkswagen  CC 4motion  2013     Compact Cars    All-Wheel Drive
#
#                trans          fuelType  cylinders  displ  pv2  pv4     city  \
# 0    Automatic (AM6)  Premium Gasoline          6    3.8   79    0  16.4596
# 1  Automatic (AM-S6)  Premium Gasoline          4    2.0   94    0  21.8706
# 2     Automatic (S6)  Premium Gasoline          6    3.6   94    0  17.4935
# 3     Automatic (S6)  Premium Gasoline          6    3.6   94    0  16.9415
#
#      UCity  highway  UHighway     comb  co2  feScore  ghgScore
# 0  20.2988  22.5568   30.1798  18.7389  471        4         4
# 1  26.9770  31.0367   42.4936  25.2227  349        6         6
# 2  21.2000  26.5716   35.1000  20.6716  429        5         5
# 3  20.5000  25.2190   33.5000  19.8774  446        5         5

# %% [markdown]
# # Exercise 1: Scatter Plots

# %% [markdown]
# Let's look at the relationship between fuel mileage ratings for city vs. highway driving, as stored in the 'city' and 'highway' variables (in miles per gallon, or mpg). **Use a _scatter plot_ to depict the data.**
#
# 1. What is the general relationship between these variables?
# 2. Are there any points that appear unusual against these trends?
# 3. (Optional) Plot a dotted, red, diagonal line from the lower right to upper left of the plot for comparison.

# %%
fig, axes = plt.subplots(1,2,figsize=(15,8))

axes[0].scatter(data=df, x='city', y='highway')

axes[1].scatter(data=df, x='city', y='highway')
axes[1].axline((10, 10), slope=1)

;
# Out:
# ''

# %% [markdown]
# 1. There seems to be a positive relationship
# 2. There are lots of outliers
# 3. Done

# %% [markdown]
# # Exercise 2: Heat map

# %% [markdown]
# Let's look at the relationship between two other numeric variables. How does the engine size relate to a car's CO2 footprint? The 'displ' variable has the former (in liters), while the 'co2' variable has the latter (in grams per mile). **Use a heat map (2d hist) to depict the data.** How strong is this trend?

# %%
plt.hist2d(data=df, x='displ', y='co2',cmin=1, cmap='viridis_r');

# %%
bins_x = np.arange(0.6, 7+0.3, 0.3)
bins_y = np.arange(0, 700, 30)


plt.hist2d(data=df, x='displ', y='co2',cmin=0.1, cmap='viridis_r', bins=[bins_x, bins_y])
plt.colorbar()

;
# Out:
# ''

# %% [markdown]
# it's a positive trend. A majority of engines that produce between 250-400 grams per mile temnd to tbe in the 1.5-2 liter range.

# %% [markdown]
# # Exercise 3: Box Plot

# %% [markdown]
# Use a box plot to explore the relationship between the fuel type and the engine size.  Fuel type classes can be found in the `VClass` column, while the engine sizes are in the `displ` column (in liters). Make sure to properly order your fuel classes (for example, plot from regular to premium gasoline, or vice-versa).

# %%
plt.figure(figsize=(12,4))

grouped = df.loc[:,['fuelType', 'displ']] \
    .groupby(['fuelType']) \
    .mean() \
    .sort_values(by='displ')

sns.boxplot(data=df, x='fuelType', y='displ', order=grouped.index[::-1])
;
# Out:
# ''

# %% [markdown]
# It's sorted by median.
#
# There aren't many midgrade gasoline vehicles but they have the highest median followed by premium gasoline, regular gas, diesel and natural gas. Premium and regular gas have the kargest variation, porbably because they are used a lot more than the others.

# %% [markdown]
# # Exercise 4: Violen Plot

# %% [markdown]
# Use a violin plot to explore the relationship between the drive type and highway performance. Drive type includes "all-wheel drive", "manual", etc. Drive type can be found in the `drive` column, while highway efficiency in `highway`.

# %%
grouped = df.loc[:,['drive', 'highway']] \
    .groupby(['drive']) \
    .mean() \
    .sort_values(by='highway')

plt.figure(figsize=(12,4))
sns.violinplot(data=df, x='drive', y='highway', order=grouped.index[::-1])

;
# Out:
# ''

# %% [raw]
# Front wheel drive cars tend to have the most milage followed by all-wheel, 4 wheel, rear wheel and part time 4 wheel. There isn't enough information to conclude anything about automatic A1 cars.
#
# 4-wheel drive cars seem to have a large grouping in it's distribution towards the median.
