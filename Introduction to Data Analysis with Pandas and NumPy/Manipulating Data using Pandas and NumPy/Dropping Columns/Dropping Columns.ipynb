# %% [markdown]
# # Importing libraries

# %%
import pandas as pd

# %% [markdown]
# # Reading data

# %%
df08 = pd.read_csv('all_alpha_08.csv')
df18 = pd.read_csv('all_alpha_18.csv')

# %%
df08
# Out:
#             Model  Displ      Cyl    Trans Drive      Fuel Sales Area Stnd  \
# 0       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 1       ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 2       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# 3       ACURA RDX    2.3  (4 cyl)  Auto-S5   4WD  Gasoline         FA   B5
# 4        ACURA RL    3.5  (6 cyl)  Auto-S5   4WD  Gasoline         CA   U2
# ...           ...    ...      ...      ...   ...       ...        ...  ...
# 2399  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2400  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         CA   U2
# 2401  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   2WD  Gasoline         FA   B5
# 2402  VOLVO XC 90    3.2  (6 cyl)  Auto-S6   4WD  Gasoline         FA   B5
# 2403  VOLVO XC 90    4.4  (8 cyl)  Auto-S6   4WD  Gasoline         FA   B5
#
# ...

# %%
df18
# Out:
#             Model  Displ  Cyl       Trans Drive                  Fuel  \
# 0       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 1       ACURA RDX    3.5  6.0  SemiAuto-6   2WD              Gasoline
# 2       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 3       ACURA RDX    3.5  6.0  SemiAuto-6   4WD              Gasoline
# 4       ACURA TLX    2.4  4.0       AMS-8   2WD              Gasoline
# ...           ...    ...  ...         ...   ...                   ...
# 1606  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1607  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1608  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD              Gasoline
# 1609  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
# 1610  VOLVO XC 90    2.0  4.0  SemiAuto-8   4WD  Gasoline/Electricity
#
#      Cert Region       Stnd            Stnd Description  Underhood ID  \
# ...

# %% [markdown]
# # Viewing the column names

# %%
df08.columns, df18.columns
# Out:
# (Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Sales Area', 'Stnd',
#         'Underhood ID', 'Veh Class', 'Air Pollution Score', 'FE Calc Appr',
#         'City MPG', 'Hwy MPG', 'Cmb MPG', 'Unadj Cmb MPG',
#         'Greenhouse Gas Score', 'SmartWay'],
#        dtype='object'),
#  Index(['Model', 'Displ', 'Cyl', 'Trans', 'Drive', 'Fuel', 'Cert Region',
#         'Stnd', 'Stnd Description', 'Underhood ID', 'Veh Class',
#         'Air Pollution Score', 'City MPG', 'Hwy MPG', 'Cmb MPG',
#         'Greenhouse Gas Score', 'SmartWay', 'Comb CO2'],
#        dtype='object'))

# %% [markdown]
# ## Viewing names of columns not found in both datasets

# %%
from collections import Counter


diff = list((Counter(df08) - Counter(df18)).elements())

print(diff)

diff = list((Counter(df18) - Counter(df08)).elements())

print(diff)
# Out:
# ['Sales Area', 'FE Calc Appr', 'Unadj Cmb MPG']
# ['Cert Region', 'Stnd Description', 'Comb CO2']

# %% [markdown]
# # Dropping the columns not needed

# %% [markdown]
# The columns that should be removed from the 2008 dataset are: 'Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'. Though I don't know why

# %%
df08.drop([ 'Stnd', 'Underhood ID', 'FE Calc Appr', 'Unadj Cmb MPG'],axis=1, inplace=True)

df08.head(1)
# Out:
#        Model  Displ      Cyl    Trans Drive      Fuel Sales Area Veh Class  \
# 0  ACURA MDX    3.7  (6 cyl)  Auto-S5   4WD  Gasoline         CA       SUV
#
#   Air Pollution Score City MPG Hwy MPG Cmb MPG Greenhouse Gas Score SmartWay
# 0                   7       15      20      17                    4       no

# %% [markdown]
# The columns that should be removed from the 2018 dataset are: 'Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2'

# %%
df18.drop([ 'Stnd', 'Stnd Description', 'Underhood ID', 'Comb CO2'], axis=1,inplace=True)

df18.head(1)
# Out:
#        Model  Displ  Cyl       Trans Drive      Fuel Cert Region  Veh Class  \
# 0  ACURA RDX    3.5  6.0  SemiAuto-6   2WD  Gasoline          FA  small SUV
#
#    Air Pollution Score City MPG Hwy MPG Cmb MPG  Greenhouse Gas Score SmartWay
# 0                    3       20      28      23                     5       No

# %% [markdown]
# # Saving the new datasets

# %%
df08.to_csv('data_08_v1.csv',index=False)
df18.to_csv('data_18_v1.csv',index=False)
